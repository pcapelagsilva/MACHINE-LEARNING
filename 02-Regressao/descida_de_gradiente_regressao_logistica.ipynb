# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# 1. SIMULAÇÃO DE DADOS BIOLÓGICOS
# Vamos imaginar 100 amostra com 2 biomarcadores (Expressão do Gene A e Gene B)
np.random.seed(42)
x = np.random.randn(100, 2)
# Rótulos: Se a soma da expresão for positiva, a célula é "Saudável" (1), senão "Doente" (2)
y = (x[:, 0] + x[:, 1 ] > 0).astype(int)

# 2. DIVISÃO DOS DADOS (Treino e Teste)
# Importante para o GitHub: Mostra que sabemos avaliar o modelo!!
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# 3. ESCALONAMENTO (Feature Scaling)
# Essencial para convergência rápida
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# 4. TREINANDO O MODELO
# Aqui a Descida de Gradiente é executada por baixo dos panos
model = LogisticRegression()
model.fit(x_train_scaled, y_train)

# 5. PREDIÇÕES E AVALIAÇÃO
y_pred = model.predict(x_test_scaled)
probabilidade = model.predict_proba(x_test_scaled)[:, 1]

# 6. VISUALIZAÇÃO DA FRONTEIRA DE DECISÃO
def plot_decision_boundary(x, y, model, title):
    h = .02 # tamanho do passo na malha
    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)
    plt.scatter(x[:, 0], x[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
    plt.title(title)
    plt.xlabel("Expressão Gene A")
    plt.ylabel("Expressão Gene B")

plt.figure(figsize=(10, 6))
plot_decision_boundary(x_train_scaled, y_train, model, "Limite de Decisão - Treino")
plt.show()

# 7. RELATÓRIO FINAL (Ótimo para o README do GitHub)
print("--- RELATÓRIO DE PERFORMANCE ---")
print(classification_report(y_test, y_pred))
print(f"Pesos aprendidos (w): {model.coef_}")
print(f"Viés aprendido (b): {model.intercept_}")

# %% [markdown]
# --- RELATÓRIO DE CLASSIFICAÇÃO ---
#     - PRECISION (Precisão) --> De todas as vezes que o modelo previu "Maligno" (Classe 1), quantas vezes ele relamente era maligno? Como o valor é 1.00, ele acertou todas; não houve falsos positivos.
#
#     - RECALL (Revocação/Sensibilidade) --> De todos os casos que eram realmente "Maligno", quantos o modelo identificou? 1.00 significa que ele capturou todos os casos reais; não houve falsos negativos.
#
#     - F1-SCORE --> É a medida harmônica entre a Precisão e o Recall, sendo a melhor métrica para ver o equilíbrio do modelo. Nesse caso 1.00 é o valor máximo possível (perfeito).
#
#     - SUPPORT (Suporte) --> Indica quantos exemplos de cada classe existiam no seu conjunto de teste. Assim nossa base tinha 12 exemplos da classe 0 e 8 exemplos da classe 1.

# %% [markdown]
# --- MÉDIAS DE ACURÁCIA ---
#     - ACCURACY (Acurácia) --> É a porcentagem total de acertos. Nesse caso, acertamos 20 dos 20 exemplos (1.00 ou 100%).
#
#     - MACRO AVG --> Calcula a média das métricas (precisão, recall, etc.) para cada classe, sem levar em conta o peso de quantas amostras existem.
#
#     - WEIGHTED AVG --> Calcula a média levando em conta o suporte (se uma classe tem muito mais dados que a outra, ela "pesa" mais na média). No nosso caso, como tudo é 1.00, ambas as médias são iguais.

# %% [markdown]
# --- PARÂMETROS APRENDIDOS ---
# Esses são os valores que a Descida de Gradiente encontrou para minimizar a função de custo:
#     - Pesos aprendidos (w) = [[2.2241, 2.5800]]:
#         - Como usamos dois recursos (ex: Gene A e Gene B), o modelo atribuiu um "peso" para cada um.
#         - Veja que ambos são positivos, indicando que quanto MAIOR o valor dessas características, MAIOR é a probabilidade de o resultado ser a Classe 1.
#
#     - Viés aprendido (b) = [-0.2417]:
#         - É o valor de ajuste (intercepto), que desloca a fronteira de decisão para longe ou para perto da origem

# %% [markdown]
# --- QUAL O PRÓXIMO PASSO DO COMPUTADOR ---
# Quando dermos um novo dado para ele, ele fará a conta que estudamos:
#
#                 z = (w*x1) + (w*x2) + b
#             z = (2.22*x1) + (2.58*x2) - 0.24
#
# Depois, ele passa esse "z" pela Sigmoide. Se o resultado for >0.5, ele classfica como 1.
